# %%
#@title 一、查看显卡情况
# !nvidia-smi

# %%
#@title 二、下载源码
# !git clone https://github.com/Weizhi-Zhong/IP_LAP
# Out:
# Cloning into 'IP_LAP'...
# remote: Enumerating objects: 127, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 127 (delta 30), reused 3 (delta 3), pack-reused 81
# Receiving objects: 100% (127/127), 6.71 MiB | 22.90 MiB/s, done.
# Resolving deltas: 100% (46/46), done.

# %%
#@title 三、安装虚拟环境
# Install Virtual Environment
# miniconda
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# !chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
# !bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.8/site-packages/')
# !conda install python=3.7 -y
# !python --version
# !conda create --name IP_LAP python=3.7 -y
# !source activate IP_LAP
# Out:
# --2023-08-20 04:31:25--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   209MB/s    in 0.4s
#
# 2023-08-20 04:31:26 (209 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
# ...

# %%
#@title 四、安装依赖
# 注释掉lws,不然会报错
# %cd /content/IP_LAP
# !pip install typing_extensions==4.6.3  opencv-contrib-python==4.6.0.66 opencv-python==4.6.0.66 numpy==1.21.6 tqdm==4.64.1
# !pip install mediapipe==0.8.11 face-alignment==1.3.5 librosa==0.9.2 scipy==1.4.1
# Out:
# /content/IP_LAP
# ...
#      |████████████████████████████████| 67.1 MB 38 kB/s
# ...
#      |████████████████████████████████| 60.9 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 50.3 MB/s
# ...
#      |████████████████████████████████| 78 kB 6.3 MB/s
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.42.1
#     Uninstalling tqdm-4.42.1:
#       Successfully uninstalled tqdm-4.42.1
# ...
#      |████████████████████████████████| 31.5 MB 1.4 MB/s
# ...
#      |████████████████████████████████| 214 kB 60.3 MB/s
# ...
#      |████████████████████████████████| 26.1 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 61 kB 7.9 MB/s
# ...
#      |████████████████████████████████| 11.2 MB 57.7 MB/s
# ...
#      |████████████████████████████████| 126 kB 59.0 MB/s
# ...
#      |████████████████████████████████| 1.0 MB 55.6 MB/s
# ...
#      |████████████████████████████████| 13.5 MB 54.0 MB/s
# ...
#      |████████████████████████████████| 887.5 MB 5.0 kB/s
# ...
#      |████████████████████████████████| 3.5 MB 48.0 MB/s
# ...

# %%
# 安装torchvision
# !pip install torchvision lws==1.2.7
# Out:
# ...
#      |████████████████████████████████| 24.2 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 150 kB 59.1 MB/s
# ...
#   Created wheel for lws: filename=lws-1.2.7-cp37-cp37m-linux_x86_64.whl size=777309 sha256=a176693d255f6fa594b42fc1a6c9b8f64f66b76af580050272004244507bcead
#   Stored in directory: /root/.cache/pip/wheels/49/64/9f/41e688cdc1770edf29e40b9cb2cc3ecbbae522eb969a74653a
# Successfully built lws
# ...

# %%
#@title 五、下载预训练模型
# # 这里需要提前将权重上传到网盘，再进行下载，我这边用的是我自己的分享链接，后期后关闭
# %cd /content/IP_LAP/test/checkpoints
# !gdown https://drive.google.com/uc\?id\=1E2DF_v46Kt0nKHgpFYFFXn1_EQoAtXSo
# !gdown https://drive.google.com/uc\?id\=13PFJQNv_9g6Y_l7XeLpipy3GAaig-U6g
# Out:
# /content/IP_LAP/test/checkpoints
# Downloading...
# From: https://drive.google.com/uc?id=1E2DF_v46Kt0nKHgpFYFFXn1_EQoAtXSo
# To: /content/IP_LAP/test/checkpoints/landmarkgenerator_checkpoint.pth
# 100% 167M/167M [00:03<00:00, 53.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=13PFJQNv_9g6Y_l7XeLpipy3GAaig-U6g
# To: /content/IP_LAP/test/checkpoints/renderer_checkpoint.pth
# 100% 308M/308M [00:04<00:00, 76.7MB/s]

# %%
# ##############
# # 下载自己训练的模型
# ##############
# %cd /content/IP_LAP/test/checkpoints
# !gdown https://drive.google.com/uc\?id\=1U4F7rbxjfZ1ei7pX6KRs0XvQw2XurgyG
# !gdown https://drive.google.com/uc\?id\=17Araz6nJx1_u6-FSMJWVma-DZ7BvJkJh

# %%
#@title 六、进行推理
# 带landmark
# 改代码inference_single.py  line 34 fa = face_alignment.FaceAlignment(face_alignment.LandmarksType.TWO_D, flip_input=False, device='cuda')
# %cd /content/IP_LAP
# !python inference_single.py --input '/content/IP_LAP/test/template_video/987.mp4' --audio '/content/IP_LAP/test/template_video/820.mp3' --landmark_gen_checkpoint_path '/content/IP_LAP/test/checkpoints/landmarkgenerator_checkpoint.pth' --renderer_checkpoint_path '/content/IP_LAP/test/checkpoints/renderer_checkpoint.pth'
# Out:
# /content/IP_LAP
#  landmark_generator_model loaded from :  /content/IP_LAP/test/checkpoints/landmarkgenerator_checkpoint.pth
#  renderer loaded from :  /content/IP_LAP/test/checkpoints/renderer_checkpoint.pth
# Load checkpoint from: /content/IP_LAP/test/checkpoints/landmarkgenerator_checkpoint.pth
# /usr/local/lib/python3.7/site-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and may be removed in the future, "
# /usr/local/lib/python3.7/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
# ...

# %%
# # 用自己训练的模型进行推理
# # 改代码inference_single.py  line 34 fa = face_alignment.FaceAlignment(face_alignment.LandmarksType.TWO_D, flip_input=False, device='cuda')
# %cd /content/IP_LAP
# !python inference_single.py --input '/content/IP_LAP/test/template_video/7777.mp4' --audio '/content/IP_LAP/test/template_video/813.mp3' --landmark_gen_checkpoint_path '/content/IP_LAP/test/checkpoints/landmarkgenerator_checkpoint.pth' --renderer_checkpoint_path '/content/IP_LAP/test/checkpoints/renderer_checkpoint.pth'

# %%
# 截取右边视频，用于后期超分。
import cv2
import os
def VideoCroppingRight(input_video_path, out_video_path):
    # if not os.path.exists(input_video_path):
    #     print('输入的视频文件不存在')
    video_read_cap = cv2.VideoCapture(input_video_path)
    input_video_width = int(video_read_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    input_video_height = int(video_read_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    # 根据视频调整fps
    input_video_fps = 25
    input_video_fps = int(video_read_cap.get(cv2.CAP_PROP_FPS))
    input_video_fourcc = int(cv2.VideoWriter_fourcc('M', 'P', '4', 'V'))
    out_video_width = int(input_video_width/2)
    out_video_height = input_video_height
    out_video_size = (int(out_video_width), int(out_video_height))
    video_write_cap = cv2.VideoWriter(out_video_path, input_video_fourcc, input_video_fps, out_video_size)
    while video_read_cap.isOpened():
        result, frame = video_read_cap.read()
        if not result:
            break
        # 设置裁剪范围  参数1 是高度的范围，参数2是宽度的范围
        # 左边部分
        # target = frame[0:int(input_video_height), 0:int(out_video_width)]
        # 右边部分
        target = frame[0:int(input_video_height), int(out_video_width):int(input_video_width)]
        video_write_cap.write(target)
        # cv2.imshow('target', target)
        cv2.waitKey(10)

    video_read_cap.release()
    video_write_cap.release()
    cv2.destroyAllWindows()
if __name__ == '__main__':
   VideoCroppingRight('/content/IP_LAP/test_result/4444result_N_25_Nl_15.mp4', '/content/IP_LAP/test_result/output.mp4')

# %%
#@title 七、安装GFPGAN
# 下载GFPGAN的源码
# %cd /content
# !git clone https://github.com/TencentARC/GFPGAN

# 安装依赖并下载Wav2Lip-GFPGAN的权重
# %cd /content/GFPGAN
# !pip install basicsr facexlib gradio
# !pip install -r requirements.txt
# !python setup.py develop
# !wget https://github.com/TencentARC/GFPGAN/releases/download/v1.3.0/GFPGANv1.3.pth -P '/content/GFPGAN/experiments/pretrained_models'
# Out:
# /content
# Cloning into 'GFPGAN'...
# remote: Enumerating objects: 523, done.
# remote: Total 523 (delta 0), reused 0 (delta 0), pack-reused 523
# Receiving objects: 100% (523/523), 5.39 MiB | 17.65 MiB/s, done.
# Resolving deltas: 100% (264/264), done.
# /content/GFPGAN
# ...
#      |████████████████████████████████| 172 kB 12.0 MB/s
# ...
#      |████████████████████████████████| 59 kB 5.9 MB/s
# ...
#      |████████████████████████████████| 20.0 MB 1.5 MB/s
# ...
#      |████████████████████████████████| 840 kB 53.2 MB/s
# ...
#      |████████████████████████████████| 294 kB 55.3 MB/s
# ...
#      |████████████████████████████████| 670 kB 59.1 MB/s
# ...
#      |████████████████████████████████| 5.7 MB 52.6 MB/s
# ...
#      |████████████████████████████████| 250 kB 61.0 MB/s
# ...
#      |████████████████████████████████| 177 kB 54.0 MB/s
# ...
#      |████████████████████████████████| 129 kB 55.8 MB/s
# ...
#      |████████████████████████████████| 11.3 MB 38.2 MB/s
# ...
#      |████████████████████████████████| 84 kB 3.4 MB/s
# ...

# %%
#@title 八、进行超分处理
# %cd /content
# !rm -rf images
# !rm -rf hd_images
# !rm -rf output
# !mkdir output
# !mkdir hd_images
# !mkdir images

# 自行更改视频路径 帧率-r 25 # -r 30
# !ffmpeg -i /content/IP_LAP/test_result/output.mp4   -r 25  /content/images/%5d.png

# 提取视频中的音频，用于后续处理
# !ffmpeg -i /content/IP_LAP/test_result/4444result_N_25_Nl_15.mp4  /content/output/final.mp3

# 运行GFPGAN推理，-s 2 改成 -s 1 ，下调上采样
# %cd /content/GFPGAN
# !python inference_gfpgan.py -i /content/images -o /content/hd_images -v 1.3 -s 1 --only_center_face --bg_upsampler None

# 合并成高清视频
# ffmpeg 将文件中每一帧图片合并成mp4 ，帧率-r 25 # -r 30
# %cd /content/hd_images/restored_imgs
# !ffmpeg -framerate 25 -i %05d.png  -pix_fmt yuv420p  /content/hd_images/results.mp4
# %cd /content
# 音视频合成
# !ffmpeg -i /content/hd_images/results.mp4  -i /content/output/final.mp3 -c copy /content/output/final.mp4
print('恭喜您高清数字人视频合并成功,')
# Out:
# /content
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
